# %%
import numpy as	np;
import numpy.random as nr;
import scipy.linalg as LA;
import matplotlib.pyplot as plt;
import math;

# %%
time_index = np.arange(0.01, 1.01, 0.01)

# %%
bm_cov = np.tril(np.ones([100, 100])) @ np.triu(np.ones([100, 100])) / 100

# %%
bm_plot = np.array([np.linalg.cholesky(bm_cov).dot(np.random.normal(loc=0, scale=1, size=100)) for _ in range (10)])

# %%
brownian_motion = np.insert(np.array([np.linalg.cholesky(bm_cov).dot(np.random.normal(loc=0, 
                                                                                      
                                                 scale=1, size=100)) for _ in range(10)]), obj=0, values=0,axis=1)

# %%
e_base = np.array([math.exp(i/2) for i in np.insert(time_index,0,0)])

# %%
X_t = e_base * np.cos(brownian_motion)

# %%
plt.figure(figsize=(15,5))
plt.title("$X_t$ Proccess")
for  i in X_t:
    plt.plot(i)

# %%
from math import sqrt
from scipy.stats import norm
import numpy as np


def brownian(x0, n, dt, delta, out=None):
     x0 = np.asarray(x0)

    # For each element of x0, generate a sample of n numbers from a
    # normal distribution.
          r = norm.rvs(size=x0.shape + (n,), scale=delta*sqrt(dt))

    # If `out` was not given, create an output array.
        if out is None:
        out = np.empty(r.shape)

    # This computes the Brownian motion by forming the cumulative sum of
    # the random samples. 
        np.cumsum(r, axis=-1, out=out)

    # Add the initial condition.
        out += np.expand_dims(x0, axis=-1)

        return out
# Out:
#   File "<tokenize>", line 11
#     r = norm.rvs(size=x0.shape + (n,), scale=delta*sqrt(dt))
#     ^
# IndentationError: unindent does not match any outer indentation level

# %%
import numpy
from pylab import plot, show, grid, xlabel, ylabel

# The Wiener process parameter.
delta = 2
# Total time.
T = 10.0
# Number of steps.
N = 500
# Time step size
dt = T/N
# Number of realizations to generate.
m = 20
# Create an empty array to store the realizations.
x = numpy.empty((m,N+1))
# Initial values of x.
x[:, 0] = 50

brownian(x[:,0], N, dt, delta, out=x[:,1:])

t = numpy.linspace(0.0, N*dt, N+1)
for k in range(m):
    plot(t, x[k])
xlabel('t', fontsize=16)
ylabel('x', fontsize=16)
grid(True)
show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-b62bd183b7cc> in <module>
#      17 x[:, 0] = 50
#      18
# ---> 19 brownian(x[:,0], N, dt, delta, out=x[:,1:])
#      20
#      21 t = numpy.linspace(0.0, N*dt, N+1)
#
# NameError: name 'brownian' is not defined
